# %%
import pandas as pd
df= pd.read_csv('./SET50_2D.csv')
df.dropna(how='any',inplace=True)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>HL</th>
#       <th>OC</th>
#       <th>OC/HL</th>
#       <th>SUM</th>
#       <th>T10</th>
#       <th>T01</th>
#       <th>T02</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017/3/1</td>
#       <td>3</td>
#       <td>2</td>
#       <td>6</td>
#       <td>30,308</td>
#       <td>(4,354)</td>
#       <td>6,250</td>
#       <td>28,412</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2017/3/2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>7</td>
#       <td>(35,155)</td>
#       <td>(15,723)</td>
#       <td>(9,744)</td>
# ...

# %%
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go

py.sign_in(username='colamas', api_key='SD61qqxbo3EKFw0QPjlc')
df= pd.read_csv('./SET50_2D.csv',
                index_col=0,
                parse_dates=[0],
                        header=0,
                        nrows=2000)
df.dropna(how='any',inplace=True)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>HL</th>
#       <th>OC</th>
#       <th>OC/HL</th>
#       <th>SUM</th>
#       <th>T10</th>
#       <th>T01</th>
#       <th>T02</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-03-01</th>
#       <td>3</td>
#       <td>2</td>
#       <td>6</td>
#       <td>30308</td>
#       <td>-4354</td>
#       <td>6250</td>
#       <td>28412</td>
#     </tr>
#     <tr>
#       <th>2017-03-02</th>
#       <td>2</td>
#       <td>2</td>
# ...

# %%
import numpy as np
table = pd.pivot_table(df, index=['HL'], columns= ['OC/HL'], values = ['SUM'], aggfunc=[np.sum], margins=True)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="11" halign="left">sum</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th colspan="11" halign="left">SUM</th>
#     </tr>
#     <tr>
#       <th>OC/HL</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>HL</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go

py.sign_in(username='colamas', api_key='SD61qqxbo3EKFw0QPjlc')
df= pd.read_csv('./SET50_2D.csv')
from pivottablejs import pivot_ui
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
